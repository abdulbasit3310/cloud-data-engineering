# %% [markdown]
# ## INTRODUCTION

# %%
print("python")

# %%
print(33)

# %%
print("My name is Abdul Basit","I am a student of SMIT")

# %%
print("My name is Abdul Basit","I am a student of SMIT", sep = '-')

# %% [markdown]
# ## Variables

# %%
# A container to store value or data 
name = "Abdul Basit"

# variable name -- name

print(name)

print("name")

# %% [markdown]
# ## DATA TYPES

# %%
# Data types in python

"""
String -- 'Abdul Basit'
Integer -- 33
Float -- 3.14  
Boolean -- True or False
"""

# %%
age = 23
print(age)
type(age)

# %%
# string concatenation
first_name = "Abdul"
last_name = "Basit"
print(first_name + last_name)
print(first_name * last_name) #counter error as string can not be multiplied by string

# %%
# TYPE CONVERSION
# int ()
# str ()
# float ()

# %%
score = "100"

value = int(score) + 50 # converting string to integer and then adding 50 to it
print(value)

# %%
value = float(score) + 50
print(value)

# %%
age = 10
print(type(str(age)))

# %%
subject = "math 1"
int(subject) # counter error as string can not be converted to integer

# %%
player1 = "Max Verstappen"
player2 = "Lewis Hamilton"

print(player1 , player2)

# %%
player1 = "Charles Leclerc"
print(player1) # this will update the value of player1 to "Charles Leclerc" and print it

# %%
is_raining = True
print(type(is_raining))

# %% [markdown]
# ## INPUT

# %%
# INPUT FUNCTION
subject = input("Enter the subject you want to study: ")
print(subject)

# %% [markdown]
# ## OPERATORS

# %%
print(10+3)

# %%
num_1 = int(input("Enter first number: "))
num_2 = int(input("Enter second number: "))

print("First number: ", num_1)
print("Second number: ", num_2)

answer = num_1 + num_2
print(answer)

# %%
print(f"First number: {num_1}") # f-string is used to format the string and print the value of num_1 in it

# %%
num_1 = 10
num_2 = 3

print(num_1 / num_2)
print(num_1 % num_2)

# %%
# equality operator
value_1 = 5
value_2 = 6

# print(value_1  value_2)
# print(value_1 ! value_2)

print(value_1 < value_2)
print(value_1 > value_2)

print(value_1 <= value_2)
print(value_1 >= value_2)
# Out:
# True
# False
# True
# False
